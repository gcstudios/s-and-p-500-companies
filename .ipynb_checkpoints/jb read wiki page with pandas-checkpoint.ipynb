# %%
# %time %run -i '/Users/jon/Python/notebooks/setup.ipynb'
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#  Today is: 2019-03-26
#  Yesterday is: 2019-03-25
#  Yesterday is: 20190325
#  One year ago is: 2018-03-26
#  Latest month end is: 2019-02-28 00:00:00
#  Latest month end is: 2019-02-28
#  Previous Business Day is: 20190325
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Finished running setup.py
# CPU times: user 102 ms, sys: 37.7 ms, total: 140 ms
# Wall time: 174 ms

# %%
##want to keep the ciks...
url="https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %%
df=pd.read_html(url, header=0,converters={'CIK': lambda x: str(x)}) ##$need to get CIK as STR with leading zeroes

# %%
df[0]
# Out:
#                        Security Symbol SEC filings             GICS Sector  \
# 0                    3M Company    MMM     reports             Industrials
# 1           Abbott Laboratories    ABT     reports             Health Care
# 2                   AbbVie Inc.   ABBV     reports             Health Care
# 3                   ABIOMED Inc   ABMD     reports             Health Care
# 4                 Accenture plc    ACN     reports  Information Technology
# 5           Activision Blizzard   ATVI     reports  Communication Services
# 6             Adobe Systems Inc   ADBE     reports  Information Technology
# 7    Advanced Micro Devices Inc    AMD     reports  Information Technology
# 8            Advance Auto Parts    AAP     reports  Consumer Discretionary
# 9                      AES Corp    AES     reports               Utilities
# ..                          ...    ...         ...                     ...
# ...

# %%
df[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 9 columns):
# Security                 505 non-null object
# Symbol                   505 non-null object
# SEC filings              505 non-null object
# GICS Sector              505 non-null object
# GICS Sub Industry        505 non-null object
# Headquarters Location    505 non-null object
# Date first added         402 non-null object
# CIK                      505 non-null object
# Founded                  171 non-null object
# dtypes: object(9)
# memory usage: 35.6+ KB

# %%
df[0].shape
# Out:
# (505, 9)

# %%
os.getcwd()
# Out:
# '/Users/jon/Python/notebooks/Stock Level Data and Indices/s-and-p-500-companies'

# %%
df[0].to_hdf('/Users/jon/Python/data/AWSgcsfirsttry/spxcid_hdf.h5',key='df',mode='w')
##need to check for types of each col??
# https://stackoverflow.com/questions/22998859/hdfstore-with-string-columns-gives-issues
# https://github.com/pandas-dev/pandas/issues/4415
# Out:
# /Users/jon/anaconda/envs/python36/lib/python3.6/site-packages/pandas/core/generic.py:1282: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['Security', 'Symbol', 'SEC filings', 'GICS Sector', 'GICS Sub Industry', 'Headquarters Location', 'Date first added', 'CIK', 'Founded']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
test=pd.read_hdf('/Users/jon/Python/data/AWSgcsfirsttry/spxcid_hdf.h5')

# %%
test.head()
# Out:
#               Security Symbol SEC filings             GICS Sector  \
# 0           3M Company    MMM     reports             Industrials
# 1  Abbott Laboratories    ABT     reports             Health Care
# 2          AbbVie Inc.   ABBV     reports             Health Care
# 3          ABIOMED Inc   ABMD     reports             Health Care
# 4        Accenture plc    ACN     reports  Information Technology
#
#                 GICS Sub Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota              NaN
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#           CIK      Founded
# 0  0000066740         1902
# 1  0000001800         1888
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 505 entries, 0 to 504
# Data columns (total 9 columns):
# Security                 505 non-null object
# Symbol                   505 non-null object
# SEC filings              505 non-null object
# GICS Sector              505 non-null object
# GICS Sub Industry        505 non-null object
# Headquarters Location    505 non-null object
# Date first added         402 non-null object
# CIK                      505 non-null object
# Founded                  171 non-null object
# dtypes: object(9)
# memory usage: 39.5+ KB

# %%
test.tail()
# Out:
#                    Security Symbol SEC filings             GICS Sector  \
# 500              Xylem Inc.    XYL     reports             Industrials
# 501         Yum! Brands Inc    YUM     reports  Consumer Discretionary
# 502  Zimmer Biomet Holdings    ZBH     reports             Health Care
# 503           Zions Bancorp   ZION     reports              Financials
# 504                  Zoetis    ZTS     reports             Health Care
#
#          GICS Sub Industry     Headquarters Location Date first added  \
# 500   Industrial Machinery    White Plains, New York       2011-11-01
# 501            Restaurants      Louisville, Kentucky       1997-10-06
# 502  Health Care Equipment           Warsaw, Indiana       2001-08-07
# 503         Regional Banks      Salt Lake City, Utah       2001-06-22
# 504        Pharmaceuticals  Florham Park, New Jersey       2013-06-21
#
#             CIK Founded
# 500  0001524472     NaN
# 501  0001041061     NaN
# 502  0001136869     NaN
# ...

# %%
df[0].dtypes
# Out:
# Security                 object
# Symbol                   object
# SEC filings              object
# GICS Sector              object
# GICS Sub Industry        object
# Headquarters Location    object
# Date first added         object
# CIK                      object
# Founded                  object
# dtype: object

# %%
df[0].to_csv('/Users/jon/Python/data/AWSgcsfirsttry/spxcid.csv',index=0) ##this worked clearer than hdf

# %%
junk=pd.read_csv('/Users/jon/Python/data/AWSgcsfirsttry/spxcid.csv')

# %%
junk.head()
# Out:
#               Security Symbol SEC filings             GICS Sector  \
# 0           3M Company    MMM     reports             Industrials
# 1  Abbott Laboratories    ABT     reports             Health Care
# 2          AbbVie Inc.   ABBV     reports             Health Care
# 3          ABIOMED Inc   ABMD     reports             Health Care
# 4        Accenture plc    ACN     reports  Information Technology
#
#                 GICS Sub Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota              NaN
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# ...

# %%
junk.dtypes
# Out:
# Security                 object
# Symbol                   object
# SEC filings              object
# GICS Sector              object
# GICS Sub Industry        object
# Headquarters Location    object
# Date first added         object
# CIK                       int64
# Founded                  object
# dtype: object

# %%
junk.Security
# Out:
# 0                      3M Company
# 1             Abbott Laboratories
# 2                     AbbVie Inc.
# 3                     ABIOMED Inc
# 4                   Accenture plc
# 5             Activision Blizzard
# 6               Adobe Systems Inc
# 7      Advanced Micro Devices Inc
# 8              Advance Auto Parts
# 9                        AES Corp
#                   ...
# 495          Willis Towers Watson
# 496              Wynn Resorts Ltd
# 497               Xcel Energy Inc
# 498                         Xerox
# 499                        Xilinx
# 500                    Xylem Inc.
# 501               Yum! Brands Inc
# 502        Zimmer Biomet Holdings
# 503                 Zions Bancorp
# 504                        Zoetis
# Name: Security, Length: 505, dtype: object

# %%
###ok let's not worry about datatypes for now until there's a problem.
